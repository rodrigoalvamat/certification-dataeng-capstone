# %%
import json

# %%
def get_data(file_path):

    with open(file_path, "r") as file:
        data = json.load(file)

    return data

# %%
sp500_data = get_data("./sp500.json")
sp500_symbols = []

for stock in sp500_data["stockList"]:
    sp500_symbols.append(stock["symbol"])

# %%
symbols = json.dumps(sp500_symbols)

# Write the JSON string to a file
with open("./sp500.txt", "w") as file:
    file.write(symbols)

# %%
symbols = get_data("./sp500.txt")

for symbol in symbols:
    print(symbol)
# Out:
# TRUUSD
# QNTUSD
# COMPUSD
# SGBUSD
# JSTUSD
# UNIUSD
# CVCUSD
# PLAUSD
# ORNUSD
# BNTUSD
# AVAXUSD
# AXSUSD
# KSMUSD
# SNTUSD
# ALGOUSD
# TRBUSD
# BALUSD
# BOSONUSD
# PLANETSUSD
# SCUSD
# NEARUSD
# WBTCUSD
# STXUSD
# BTTUSD
# KEEPUSD
# MIRUSD
# ALCXUSD
# ASMUSD
# GRTUSD
# CLVUSD
# ZMTUSD
# HBARUSD
# FOXUSD
# TRACUSD
# FILUSD
# UOSUSD
# AMPUSD
# ANTUSD
# SUKUUSD
# SKLUSD
# XTZUSD
# DOGEUSD
# SUSHIUSD
# CHSBUSD
# XYOUSD
# XRPUSD
# GYENUSD
# CROUSD
# API3USD
# RLYUSD
# STORJUSD
# VETUSD
# FARMUSD
# MASKUSD
# OMGUSD
# BOBAUSD
# XVGUSD
# NUUSD
# EOSUSD
# KRLUSD
# BONDUSD
# CHZUSD
# AAVEUSD
# UMAUSD
# COVALUSD
# REEFUSD
# RARIUSD
# TRIBEUSD
# COTIUSD
# XRDUSD
# MKRUSD
# UTKUSD
# BTGUSD
# RAIUSD
# BTCUSD
# IMXUSD
# IOTXUSD
# ZECUSD
# DGBUSD
# SOLUSD
# GNOUSD
# LPTUSD
# QRDOUSD
# FXUSD
# XAUTUSD
# MANAUSD
# CRPTUSD
# GALAUSD
# ICPUSD
# PAXGUSD
# DNTUSD
# SANDUSD
# NEOUSD
# GTCUSD
# VELOUSD
# 1INCHUSD
# ALBTUSD
# AVTUSD
# OCEANUSD
# DVFUSD
# OXYUSD
# BADGERUSD
# DDXUSD
# XDCUSD
# CLOUSD
# ...
